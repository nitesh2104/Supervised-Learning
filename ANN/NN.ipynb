# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("~/Projects/omscs/ML/train.csv")

df.dropna(inplace=True)
df.ffill(inplace=True)
df.bfill(inplace=True)
X = df.drop(columns=['price_range'])
y = df[['price_range']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# norm = MinMaxScaler().fit_transform(df)

# X_train_norm = norm.transform(X_train)

# X_test_norm = norm.transform(X_test)

df.values
min_max_scaler = MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(df.values)
df = pd.DataFrame(X_scaled, columns=df.columns)
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean        0.492664     0.4950     0.408900     0.509500     0.226816
# std         0.293533     0.5001     0.326402     0.500035     0.228497
# min         0.000000     0.0000     0.000000     0.000000     0.000000
# 25%         0.234302     0.0000     0.080000     0.000000     0.052632
# 50%         0.484302     0.0000     0.400000     1.000000     0.157895
# 75%         0.744322     1.0000     0.680000     1.000000     0.368421
# max         1.000000     1.0000     1.000000     1.000000     1.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500     0.484621     0.446389     0.502075     0.502929  ...
# std       0.499662     0.292673     0.320462     0.294997     0.326834  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.225806     0.111111     0.241667     0.285714  ...
# 50%       1.000000     0.483871     0.444444     0.508333     0.428571  ...
# 75%       1.000000     0.741935     0.777778     0.750000     0.857143  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.329137     0.501679     0.499255     0.521893     0.320389
# std       0.226419     0.288518     0.289880     0.300946     0.242022
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.144260     0.250167     0.254276     0.285714     0.111111
# 50%       0.287755     0.498665     0.505211     0.500000     0.277778
# 75%       0.483291     0.756342     0.750534     0.785714     0.500000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean      0.500611     0.761500      0.503000     0.507000     0.500000
# std       0.303553     0.426273      0.500116     0.500076     0.372771
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%       0.222222     1.000000      0.000000     0.000000     0.250000
# 50%       0.500000     1.000000      1.000000     1.000000     0.500000
# 75%       0.777778     1.000000      1.000000     1.000000     0.750000
# max       1.000000     1.000000      1.000000     1.000000     1.000000
#
# [8 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler. transform(X_test)

# %%
X = [[0., 0.], [0., 1.]]
y = [0, 1]
d = df

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1, warm_start=True)
clf.fit(X, y)
# Out:
# /Users/nitarora/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), random_state=1,
#               solver='lbfgs', warm_start=True)

# %%
clf.predict([[1., 0.], [1., 1.]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-6782d46989c8> in <module>
# ----> 1 clf.predict([[1., 0.], [1., 1.]])
#
# ~/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py in predict(self, X)
#    1002         """
#    1003         check_is_fitted(self)
# -> 1004         y_pred = self._predict(X)
#    1005
#    1006         if self.n_outputs_ == 1:
#
# ~/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py in _predict(self, X)
#     697                                          layer_units[i + 1])))
#     698         # forward propagate
# --> 699         self._forward_pass(activations)
#     700         y_pred = activations[-1]
#     701
#
# ~/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py in _forward_pass(self, activations)
#     103         for i in range(self.n_layers_ - 1):
#     104             activations[i + 1] = safe_sparse_dot(activations[i],
# --> 105                                                  self.coefs_[i])
#     106             activations[i + 1] += self.intercepts_[i]
#     107
#
# ~/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Projects/KBAI-Assignment1/venv/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 20 is different from 2)
